# %%
# two main concepts for this HW assignment
#(1) Extract information from this table, similar to SQL Databases
#(2) Selection Process > only one table so not as complicated as with more tables or bigger data

# %%
#import numpy as np
#import pandas as pd
#import matplotlib.pyplot as plt
#from scipy.optimize import curve_fit

# !pip install seaborn --upgrade
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

# %matplotlib inline
# Out:
# Requirement already up-to-date: seaborn in /Applications/anaconda/lib/python2.7/site-packages

# %%
import csv

# %%
#print titanic_data = pd.read_csv('titanic.csv')
#using larger named variable for this exercise, though for future will use shorter

# %%
titanic_data.head()
# Out:
#    PassengerId  Survived Pclass  \
# 0            1         0      3
# 1            2         1      1
# 2            3         1      3
# 3            4         1      1
# 4            5         0      3
#
#                                                 Name     Sex  Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male   22      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 2                             Heikkinen, Miss. Laina  female   26      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
# 4                           Allen, Mr. William Henry    male   35      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
#1
#How many passengers are in our passenger list? 
# isolating the data set for PassengerId
# also can be done as such >> dt[’PassengerId’].count() with a different variable 
print titanic_data['PassengerId'].describe()
# Out:
# count    891.000000
# mean     446.000000
# std      257.353842
# min        1.000000
# 25%      223.500000
# 50%      446.000000
# 75%      668.500000
# max      891.000000
# dtype: float64

# %%
#1
# also >> dt['PassengerId'].count()
print titanic_data['PassengerId'].count()
# Out:
# 891

# %%
titanic_data
# Out:
#      PassengerId  Survived Pclass  \
# 0              1         0      3
# 1              2         1      1
# 2              3         1      3
# 3              4         1      1
# 4              5         0      3
# 5              6         0      3
# 6              7         0      1
# 7              8         0      3
# 8              9         1      3
# 9             10         1      2
# 10            11         1      3
# 11            12         1      1
# 12            13         0      3
# 13            14         0      3
# 14            15         0      3
# 15            16         1      2
# 16            17         0      3
# 17            18         1      2
# 18            19         0      3
# 19            20         1      3
# 20            21         0      2
# 21            22         1      2
# 22            23         1      3
# 23            24         1      1
# 24            25         0      3
# 25            26         1      3
# ...

# %%
#From here forward, we’ll assume our dataset represents the full 
# passenger list for the Titanic.

# %%
#2
#What is the overall survival rate?
# also can be done as sucg >> dt[’Survived’].mean()
# comments >> what do we do in order to get the mean value? 
# comments >> must add and divide by 891 with algebra calculation
# comments >> first used descirbe for introduction student purposes, to play around, 
# comments >> and find my comfort level using pandas for the first time, though will not
# comments >> continue as such in future, and will keep it shorter, etc.
print titanic_data['Survived'].describe()
# Out:
# count    891.000000
# mean       0.383838
# std        0.486592
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        1.000000
# max        1.000000
# dtype: float64

# %%
#2
#What is the overall survival rate?
# can also be done dt['Survived'].mean()
print titanic_data[['Survived']].mean()
# Out:
# Survived    0.383838
# dtype: float64

# %%
#3 How many male passengers were onboard?
# also can be done >> dt[dt.Sex == 'male']['PassengerId'].count()
print titanic_data[['Sex']].count()
# Out:
# Sex    891
# dtype: int64

# %%
#3 How many male passengers were onboard?
# comments >> combined the two here for questions 3/4
#df.gender.value_counts()
print titanic_data['Sex'].value_counts().plot(kind = 'bar')
Gender_Breakdown = titanic_data.groupby('Sex').count()
print Gender_Breakdown['PassengerId']
# Out:
# Axes(0.125,0.125;0.775x0.775)
# Sex
# female    314
# male      577
# Name: PassengerId, dtype: int64

# %%
#4
# aldo can be done as so >> dt[dt.Sex == 'male']['Survived'].mean{}
# also can be done >> dt[dt.Sex == 'female']['PassengerId'].count()
titanic_data.Sex.unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
print titanic_data[['']]
#df[(df.native_country != 'Uited-States;) & (df.educatino_num > 9)].income.value_counts()

# %%
#5Q: What is the overall survival rate of male passengers?
#5 A: 18.89%
#comment > also can be done >> dt.[dt.Sex == 'male']['Survived'].mean()

#6 Q: What is the overall survival rate of female passengers?
#6 A: 74.20%
#can be done >> dt['Age'].mean()
# comment > also be done >> dt.[dt.Sex == 'female']['Survived'].mean()

grouped = titanic_data.groupby('Sex').mean()
print grouped['Survived']
# Out:
# Sex
# female    0.742038
# male      0.188908
# Name: Survived, dtype: float64

# %%
#attempt at scatter plot, just playing around and not for HW purposes
titanic_data.plot(kind='scatter',
        x = 'Age',
        y ='Survived',
        alpha = .25,
        figsize = (10,5))

# %%
survival_rate = pd.crosstab([titanic_data.Pclass, titanic_data.Sex], titanic_data.Survived.astype(bool))
print survival_rate.plot(kind='line', stacked=True, color=['green','blue'], grid=True);

survival_rate = pd.crosstab([titanic_data.Pclass, titanic_data.Sex], titanic_data.Survived.astype(bool))
print survival_rate.plot(kind='bar', stacked=True, color=['green','blue'], grid=True);
# Out:
# Axes(0.125,0.125;0.775x0.775)
# Axes(0.125,0.125;0.775x0.775)

# %%
#7Q: What is the average age of all passengers onboard?    
#dt[dt.Age.notnull()]['Age'].mean()
# comment > in future I would do something more like this > dt['Age'].mean(), though we get 'NaN
# which seems to produce an incorrect value, therefore selecting all values that are 'notnull'
# and divide by another number, the entrie tables numbers with an Age, for example, it is already done with
# the '.mean' function . We make it explicit with the 'notnull' function below.
# >> dt[dt.Age.notnull()]['Age'].mean  >> another way how to deal with this

print titanic_data.Age.describe()
# Out:
# count    891.000000
# mean      29.805751
# std       14.617166
# min       -9.760100
# 25%       20.000000
# 50%       28.582684
# 75%       39.000000
# max       80.000000
# dtype: float64

# %%
 #7a Q: How did you calculate this average age?
    #7a A: once describing data above, simply took the mean, as per below
print titanic_data.Age.mean()
# Out:
# 29.8057506967

# %%
#7bQ: Note that some of the passengers do not have an age value. 
        #How did you deal with this? 
#7bA: Missing 'age value' affects mean significantly, the isnull function was defined, 
# though must be method more concise. 
missing_age = titanic_data.Age.isnull()
missing_age
titanic_data[missing_age]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
  #7bQ: What are some other ways of dealing with this?
    #ONLINE SEARCH! Found helpful websites with template and remainder of steps following below
    
#7bA: isolating standard deviation, mean, view nulls
#for the null values with missing values, we complete the missing ages with n(n=normal)dlist, and calculated for std
# then added the values with ndist
#use df.iloc for localization , selecting a row/collumn 

print titanic_data[titanic_data.Age.isnull()] 
# comments again > dt[dt.Age.notnull()]['Age'].mean()
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
# Get the Mean and STD of ALL Data
# Populate tmissing age from ndist centered on avg age and std
print 'Mean Age:', titanic_data.Age.mean()
print 'Std Age:', titanic_data.Age.std()
# Out:
# Mean Age: 29.8057506967
# Std Age: 14.6171661472

# %%
# ndist with mean and std
# all entries with missing 
def get_age_impute_values(n):
    return np.random.normal(29.7, 14.5, n)

# %%
# boolean and mask to be learned here
age_missing_mask = titanic_data.Age.isnull()
age_missing_mask
titanic_data[age_missing_mask]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
# setting values with Random ndist 
#titanic_data.loc[titanic_data.Age.isnull(), 'Age'] = get_age_impute_values(n=177)

# %%
titanic_data.head(5)
# Out:
#    PassengerId  Survived Pclass  \
# 0            1         0      3
# 1            2         1      1
# 2            3         1      3
# 3            4         1      1
# 4            5         0      3
#
#                                                 Name     Sex  Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male   22      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 2                             Heikkinen, Miss. Laina  female   26      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
# 4                           Allen, Mr. William Henry    male   35      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null object
# Name           891 non-null object
# Sex            891 non-null object
# Age            891 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(4), object(6)

# %%
titanic_data['Pclass'] = titanic_data.Pclass.astype(str)

# %%
#8 What is the average age of passengers who survived?
#also can be done >> dt[dt.Survived == 1]['Age'].mean()
#comments >> using described simply for my own purposes to explore in first assignment of HW1
print titanic_data.Survived.describe()
# Out:
# count    891.000000
# mean       0.383838
# std        0.486592
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        1.000000
# max        1.000000
# dtype: float64

# %%
print titanic_data.Survived.mean()
# Out:
# 0.383838383838

# %%
#8 lists here the survived mean age as 28.582684 
# comments >> using notnull to >> select all the rows where there is a value
# comments >> best done as such dt[dt.Survived == 1]['Age'].mean()
#dt[dt.Survived == 1]['Age'].mean()
#46
#28.343689655172415
# comments >> 1 means survived
print titanic_data.Age.describe()
# Out:
# count    891.000000
# mean      29.805751
# std       14.617166
# min       -9.760100
# 25%       20.000000
# 50%       28.582684
# 75%       39.000000
# max       80.000000
# dtype: float64

# %%
#9 What is the average age of passengers who did not survive?
#9 comments >> lists here the survived mean age as 30 with the below formula
# comment >> best done as such >> dt[dt.Survived == 0]['Age'].mean()
# here 0 means no one survived 

# # 9
#49
#dt[dt.Survived == 0]['Age'].mean()
#50
#30.626179245283019

# %%
#10 At this (early) point in our analysis, what might you infer about any patterns you are seeing?
(1) More men than women were on board!
(2) Women were rescued at first!
(3) Younger people have the higher probability to survive!

# %%
#11 How many passengers are in each of the three classes of service (e.g. First, Second, Third?)
# comments >> would use this in future, simpler than above, best used for several groups displayed
# in the case, so groupby would be best to apply, for example.
#dt.groupby('Pclass')['PassengerId'].count()￼
Pclass
1         216
2         184
3         491
Name: PassengerId, dtype: int64

# %%
# can also be done as such >> three times with Pclass 1,2, and 3, though in this case with big data coming up,
# one single line, this is how it is done

#dt[dt.Pclass == 3]['PassengerId'].count()
#59
#491

# %%
#12 What is the survival rate for passengers in each of the three classes of service?
#dt.groupby('Pclass')['Survived'].mean()
# may be elementary though float >> decimal point value
# comment >> 64 more digits and information than 32 bit, more information we can save,
# comments >> more detailed data can be viewed, of course 

#Pclass
#1         0.629630
#2         0.472826
#3         0.242363
# Name: Survived, dtype: float64

# %%
#13 What else might you conclude?
# Correlation Fare/Survival ('the more you pay, the higher the probability you stay alive')
# taking a look at those who survived and those who have not survived, as well as Fare to look
# comment >> deeper into mean of both. We see fare of about 22$USD for those who did not survive, so
# comment >> interestingly enough we have the classic argument deeply hidden here for quality of life,
# comment >> great extrapolation for class of service, airflight, luxury cars, etc. when we are taking this
# comment >> towards narrative and story for where this data could go 

#dt.groupby('Survived')['Fare'].mean()
#Survived
#0           22.117887
#1           48.395408
#Name: Fare, dtype: float64

titanic_data.plot(kind='scatter',
       x = 'Fare',
       y ='Age',
       alpha = .25,
       figsize = (10,5))

# %%
#14Q: Last, if we were to build a predictive model, which features in the data do you think 
   #14(cont) we should include in the model and which can we leave out? 
    #14(cont) Why?
    
#14A: import to include columns: Age, Survived, Fare, Pclass, Sex, leave out remainder not specified
# remainder such as name of the ticket, in this case, may not be important, the cabin collumn could
# be of importance as the survival rate depends on also the Passengers location onthe ship, as far as
#where the cabin was in relation to where the fire was, etc. Name of the passenger may not be important,
# at this time, though could be if wealth and geneology was a study. 
# Survival rate implicitly given by the collumn, taking one row and looking at the value, specified
# calculations of survival chance could be calculated. The  predictive model says something about passengers(s)
# and if we know the passenger is 20yrsold and has paid amount of $ in Pclass 1 and is female, chance of survival
#is very high, if passenger 80yrsold and has 3rd class, and a male, chance of survival is lower, almost 0.
#

# using a regression method could work for this answer
