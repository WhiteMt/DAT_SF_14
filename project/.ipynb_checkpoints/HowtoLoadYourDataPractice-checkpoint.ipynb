# %% [markdown]
# - Go to https://archive.ics.uci.edu/ml/machine-learning-databases/00327/Training%20Dataset.arff
# - right click on the page and click 'Save As' and name something ending with .arff

# %%
# install 'liac-arff', a python module that can load arff files
# !pip install liac-arff
# Out:
# You are using pip version 6.1.1, however version 7.0.3 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# Collecting liac-arff
#   Downloading liac-arff-2.0.2.zip
# Installing collected packages: liac-arff
#   Running setup.py install for liac-arff
# Successfully installed liac-arff-2.0.2

# %%
# import pandas and arff
import pandas as pd
import arff
import urllib2

# %% [markdown]
# ### load the data with the path to the file and the name you gave it

# %%
# load the data, which is now stored in a dictionary

data_arff = arff.load(open('Dataset.arff', 'rb'))
#weka is .arff = JavaScript-esque format

# %%
print data_arff.keys()
# Out:
# [u'attributes', u'relation', u'description', u'data']

# %%
# get the column names by calling the key 'attributes' and getting the first value in each tuple
column_names = [x[0] for x in data_arff['attributes']]

# %%
data_arff['attributes']
# list of tuples
# Out:
# [(u'having_IP_Address', [u'1', u'0']),
#  (u'URL_Length', [u'1', u'0', u'-1']),
#  (u'Shortining_Service', [u'0', u'1']),
#  (u'having_At_Symbol', [u'0', u'1']),
#  (u'double_slash_redirecting', [u'1', u'0']),
#  (u'Prefix_Suffix', [u'-1', u'0', u'1']),
#  (u'having_Sub_Domain', [u'-1', u'0', u'1']),
#  (u'SSLfinal_State', [u'-1', u'1', u'0']),
#  (u'Domain_registeration_length', [u'0', u'1', u'-1']),
#  (u'Favicon', [u'0', u'1']),
#  (u'port', [u'0', u'1']),
#  (u'HTTPS_token', [u'1', u'0']),
#  (u'Request_URL', [u'1', u'-1']),
#  (u'URL_of_Anchor', [u'-1', u'0', u'1']),
#  (u'Links_in_tags', [u'1', u'-1', u'0']),
#  (u'SFH', [u'-1', u'1']),
#  (u'Submitting_to_email', [u'1', u'0']),
#  (u'Abnormal_URL', [u'1', u'0']),
#  (u'Redirect', [u'0', u'1']),
#  (u'on_mouseover', [u'0', u'1']),
#  (u'RightClick', [u'0', u'1']),
#  (u'popUpWidnow', [u'0', u'1']),
#  (u'Iframe', [u'0', u'1']),
#  (u'age_of_domain', [u'-1', u'0', u'1']),
#  (u'DNSRecord', [u'1', u'0']),
#  (u'web_traffic', [u'-1', u'0', u'1']),
#  (u'Page_Rank', [u'-1', u'0', u'1']),
#  (u'Google_Index', [u'0', u'1']),
#  (u'Links_pointing_to_page', [u'1', u'0', u'-1']),
#  (u'Statistical_report', [u'1', u'0']),
#  (u'Result', [u'1', u'-1'])]

# %%
data_arff['attributes'][0]
#first tuple
# Out:
# (u'having_IP_Address', [u'1', u'0'])

# %%
for x in data_arff['attributes']:
    print x
#for loop printing out each integer position, from 0 to 1, and etc.
#   print 
#print with space after creates space
# Out:
# (u'having_IP_Address', [u'1', u'0'])
# (u'URL_Length', [u'1', u'0', u'-1'])
# (u'Shortining_Service', [u'0', u'1'])
# (u'having_At_Symbol', [u'0', u'1'])
# (u'double_slash_redirecting', [u'1', u'0'])
# (u'Prefix_Suffix', [u'-1', u'0', u'1'])
# (u'having_Sub_Domain', [u'-1', u'0', u'1'])
# (u'SSLfinal_State', [u'-1', u'1', u'0'])
# (u'Domain_registeration_length', [u'0', u'1', u'-1'])
# (u'Favicon', [u'0', u'1'])
# (u'port', [u'0', u'1'])
# (u'HTTPS_token', [u'1', u'0'])
# (u'Request_URL', [u'1', u'-1'])
# (u'URL_of_Anchor', [u'-1', u'0', u'1'])
# (u'Links_in_tags', [u'1', u'-1', u'0'])
# (u'SFH', [u'-1', u'1'])
# (u'Submitting_to_email', [u'1', u'0'])
# (u'Abnormal_URL', [u'1', u'0'])
# (u'Redirect', [u'0', u'1'])
# (u'on_mouseover', [u'0', u'1'])
# (u'RightClick', [u'0', u'1'])
# (u'popUpWidnow', [u'0', u'1'])
# (u'Iframe', [u'0', u'1'])
# (u'age_of_domain', [u'-1', u'0', u'1'])
# (u'DNSRecord', [u'1', u'0'])
# (u'web_traffic', [u'-1', u'0', u'1'])
# (u'Page_Rank', [u'-1', u'0', u'1'])
# (u'Google_Index', [u'0', u'1'])
# (u'Links_pointing_to_page', [u'1', u'0', u'-1'])
# (u'Statistical_report', [u'1', u'0'])
# (u'Result', [u'1', u'-1'])

# %%
var = [x for x in data_arff['attributes']]
#var === variable , can be anything
# 2 bracket sets === mimics the for loop function 
# keeping all in a list, easy for setting the outcome to be a list, setting with a variable name
# Out:
# [(u'having_IP_Address', [u'1', u'0']),
#  (u'URL_Length', [u'1', u'0', u'-1']),
#  (u'Shortining_Service', [u'0', u'1']),
#  (u'having_At_Symbol', [u'0', u'1']),
#  (u'double_slash_redirecting', [u'1', u'0']),
#  (u'Prefix_Suffix', [u'-1', u'0', u'1']),
#  (u'having_Sub_Domain', [u'-1', u'0', u'1']),
#  (u'SSLfinal_State', [u'-1', u'1', u'0']),
#  (u'Domain_registeration_length', [u'0', u'1', u'-1']),
#  (u'Favicon', [u'0', u'1']),
#  (u'port', [u'0', u'1']),
#  (u'HTTPS_token', [u'1', u'0']),
#  (u'Request_URL', [u'1', u'-1']),
#  (u'URL_of_Anchor', [u'-1', u'0', u'1']),
#  (u'Links_in_tags', [u'1', u'-1', u'0']),
#  (u'SFH', [u'-1', u'1']),
#  (u'Submitting_to_email', [u'1', u'0']),
#  (u'Abnormal_URL', [u'1', u'0']),
#  (u'Redirect', [u'0', u'1']),
#  (u'on_mouseover', [u'0', u'1']),
#  (u'RightClick', [u'0', u'1']),
#  (u'popUpWidnow', [u'0', u'1']),
#  (u'Iframe', [u'0', u'1']),
#  (u'age_of_domain', [u'-1', u'0', u'1']),
#  (u'DNSRecord', [u'1', u'0']),
#  (u'web_traffic', [u'-1', u'0', u'1']),
#  (u'Page_Rank', [u'-1', u'0', u'1']),
#  (u'Google_Index', [u'0', u'1']),
#  (u'Links_pointing_to_page', [u'1', u'0', u'-1']),
#  (u'Statistical_report', [u'1', u'0']),
#  (u'Result', [u'1', u'-1'])]

# %%
data_arff['attributes'][0]
# ('', []) tuple with string, list
# Out:
# (u'having_IP_Address', [u'1', u'0'])

# %%
print data_arff['attributes'][0][0]
# Out:
# having_IP_Address

# %%
print data_arff['attributes'][0]

# %%
column_names = [x[0] for x in data_arff['attributes']]
#pulling out 1st position of each X, makes a list

# %%
print column_names
# Out:
# [u'having_IP_Address', u'URL_Length', u'Shortining_Service', u'having_At_Symbol', u'double_slash_redirecting', u'Prefix_Suffix', u'having_Sub_Domain', u'SSLfinal_State', u'Domain_registeration_length', u'Favicon', u'port', u'HTTPS_token', u'Request_URL', u'URL_of_Anchor', u'Links_in_tags', u'SFH', u'Submitting_to_email', u'Abnormal_URL', u'Redirect', u'on_mouseover', u'RightClick', u'popUpWidnow', u'Iframe', u'age_of_domain', u'DNSRecord', u'web_traffic', u'Page_Rank', u'Google_Index', u'Links_pointing_to_page', u'Statistical_report', u'Result']

# %%
# load the data into a pandas data frame and set the column names
df = pd.DataFrame(data_arff['data'], columns = column_names)

# %%
# data_arff === dictionary
data_arff['data']
#collect data key
# Out:
# [[u'1',
#   u'1',
#   u'0',
#   u'0',
#   u'1',
#   u'-1',
#   u'-1',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'1',
#   u'-1',
#   u'1',
#   u'-1',
#   u'1',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'1',
#   u'-1',
#   u'-1',
#   u'0',
#   u'1',
#   u'1',
#   u'1'],
#  [u'0',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'0',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'1',
#   u'0',
#   u'-1',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'1',
#   u'0',
#   u'-1',
#   u'0',
#   u'1',
#   u'0',
#   u'1'],
#  [u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'-1',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'1',
#   u'0',
#   u'-1',
#   u'-1',
#   u'1',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'1',
#   u'-1',
#   u'0',
#   u'0',
#   u'1',
#   u'1'],
#  [u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'-1',
#   u'-1',
#   u'1',
#   u'0',
#   u'0',
#   u'1',
#   u'-1',
#   u'0',
#   u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'1',
#   u'1',
#   u'-1',
#   u'0',
#   u'-1',
#   u'0',
#   u'1'],
#  [u'0',
#   u'0',
#   u'1',
#   u'0',
#   u'0',
#   u'-1',
#   u'1',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'0',
#   u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'0',
#   u'1',
#   u'0',
#   u'-1',
#   u'1',
#   u'0',
#   u'-1',
#   u'0',
#   u'1',
#   u'0',
#   u'-1'],
#  [u'1',
#   u'0',
#   u'1',
#   u'0',
#   u'1',
#   u'0',
#   u'1',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'1',
#   u'0',
#   u'0',
#   u'-1',
#   u'1',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'0',
#   u'0',
#   u'-1',
#   u'1',
#   u'-1'],
#  [u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'-1',
#   u'1',
#   u'-1',
#   u'1',
#   u'0',
#   u'1',
#   u'1',
#   u'0',
#   u'-1',
#   u'-1',
#   u'1',
#   u'1',
#   u'0',
#   u'1',
#   u'0',
#   u'1',
#   u'1',
#   u'1',
#   u'1',
#   u'1',
#   u'1',
#   u'0',
#   u'0',
#   u'1',
#   u'-1'],
#  [u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'1',
#   u'1',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'1',
#   u'1',
#   u'1',
#   u'1',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'0',
#   u'-1',
#   u'-1',
#   u'0',
#   u'-1',
#   u'1',
#   u'-1'],
#  [u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'1',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'0',
#   u'1',
#   u'-1',
#   u'1',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'0',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'-1'],
#  [u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'-1',
#   u'-1',
#   u'-1',
#   u'1',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'1',
#   u'-1',
#   u'0',
#   u'1',
#   u'1',
#   u'1'],
#  [u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'-1',
#   u'-1',
#   u'-1',
#   u'0',
#   u'0',
#   u'1',
#   u'1',
#   u'-1',
#   u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'1',
#   u'-1',
#   u'-1',
#   u'0',
#   u'1',
#   u'0',
#   u'1'],
#  [u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'1',
#   u'0',
#   u'1',
#   u'0',
#   u'1',
#   u'-1',
#   u'-1',
#   u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'0',
#   u'1',
#   u'1',
#   u'-1',
#   u'1',
#   u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'1'],
#  [u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'-1',
#   u'1',
#   u'1',
#   u'0',
#   u'0',
#   u'-1',
#   u'-1',
#   u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'0',
#   u'1',
#   u'0',
#   u'-1',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1'],
#  [u'0',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'-1',
#   u'1',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'1',
#   u'-1',
#   u'1',
#   u'1',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'1',
#   u'1',
#   u'-1',
#   u'1',
#   u'1',
#   u'1',
#   u'-1'],
#  [u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'-1',
#   u'1',
#   u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'1',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'-1'],
#  [u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'1',
#   u'1',
#   u'-1',
#   u'0',
#   u'0',
#   u'1',
#   u'1',
#   u'1',
#   u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'1',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'-1'],
#  [u'1',
#   u'-1',
#   u'1',
#   u'0',
#   u'1',
#   u'0',
#   u'1',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'1',
#   u'0',
#   u'-1',
#   u'-1',
#   u'0',
#   u'0',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'1',
#   u'1',
#   u'0',
#   u'1',
#   u'-1',
#   u'0',
#   u'-1'],
#  [u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'-1',
#   u'-1',
#   u'1',
#   u'1',
#   u'1',
#   u'0',
#   u'-1',
#   u'-1',
#   u'-1',
#   u'-1',
#   u'1',
#   u'1',
#   u'0',
#   u'1',
#   u'0',
#   u'1',
#   u'0',
#   u'-1',
#   u'1',
#   u'1',
#   u'-1',
#   u'0',
#   u'-1',
#   u'1',
#   u'1'],
#  [u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'1',
#   u'1',
#   u'0',
#   u'1',
#   u'-1',
#   u'-1',
#   u'0',
#   u'-1',
#   u'1',
#   u'1',
#   u'0',
#   u'1',
#   u'0',
#   u'1',
#   u'0',
#   u'1',
#   u'1',
#   u'-1',
#   u'-1',
#   u'0',
#   u'0',
#   u'1',
#   u'1'],
#  [u'0',
#   u'-1',
#   u'0',
#   u'1',
#   u'0',
#   u'-1',
#   u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'-1',
#   u'1',
#   u'-1',
#   u'1',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'0',
#   u'1',
#   u'-1',
#   u'0',
#   u'1',
#   u'1',
#   u'1'],
#  [u'0',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'-1',
#   u'1',
#   u'0',
#   u'0',
#   u'1',
#   u'0',
#   u'-1',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'0',
#   u'1',
#   u'0',
#   u'-1',
#   u'0',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'-1'],
#  [u'1',
#   u'1',
#   u'1',
#   u'0',
#   u'1',
#   u'1',
#   u'-1',
#   u'1',
#   u'-1',
#   u'0',
#   u'0',
#   u'1',
#   u'1',
#   u'0',
#   u'0',
#   u'1',
#   u'1',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'0',
#   u'1',
#   u'-1',
#   u'0',
#   u'1',
#   u'1',
#   u'-1'],
#  [u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'-1',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'-1',
#   u'0',
#   u'-1',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'1',
#   u'1',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'1'],
#  [u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'-1',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'-1',
#   u'-1',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'1',
#   u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'1'],
#  [u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'1',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'0',
#   u'1',
#   u'-1',
#   u'1',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'0',
#   u'1',
#   u'-1',
#   u'1',
#   u'-1',
#   u'1',
#   u'-1'],
#  [u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'1',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'1',
#   u'0',
#   u'-1',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'1'],
#  [u'0',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'1',
#   u'1',
#   u'0',
#   u'1',
#   u'0',
#   u'0',
#   u'1',
#   u'0',
#   u'0',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'0',
#   u'1',
#   u'1',
#   u'1',
#   u'1',
#   u'0',
#   u'-1',
#   u'1',
#   u'0',
#   u'0',
#   u'-1'],
#  [u'1',
#   u'-1',
#   u'1',
#   u'0',
#   u'1',
#   u'1',
#   u'-1',
#   u'1',
#   u'-1',
#   u'0',
#   u'0',
#   u'1',
#   u'1',
#   u'1',
#   u'1',
#   u'-1',
#   u'1',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'1',
#   u'1',
#   u'-1',
#   u'1',
#   u'0',
#   u'1',
#   u'-1'],
#  [u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'1',
#   u'-1',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'0',
#   u'1',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'1'],
#  [u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'0',
#   u'-1',
#   u'1',
#   u'1',
#   u'1',
#   u'1',
#   u'-1',
#   u'-1',
#   u'0',
#   u'-1',
#   u'1',
#   u'1',
#   u'0',
#   u'1',
#   u'0',
#   u'1',
#   u'0',
#   u'-1',
#   u'1',
#   u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'1',
#   u'1'],
#  [u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'1',
#   u'0',
#   u'-1',
#   u'-1',
#   u'0',
#   u'-1',
#   u'1',
#   u'1',
#   u'0',
#   u'1',
#   u'0',
#   u'1',
#   u'0',
#   u'1',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'1'],
#  [u'1',
#   u'-1',
#   u'1',
#   u'0',
#   u'1',
#   u'1',
#   u'1',
#   u'1',
#   u'1',
#   u'0',
#   u'0',
#   u'1',
#   u'1',
#   u'0',
#   u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'0',
#   u'1',
#   u'-1',
#   u'0',
#   u'1',
#   u'0',
#   u'-1'],
#  [u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'1',
#   u'-1',
#   u'1',
#   u'1',
#   u'0',
#   u'1',
#   u'0',
#   u'1',
#   u'-1',
#   u'1',
#   u'1',
#   u'0',
#   u'1',
#   u'0',
#   u'1',
#   u'0',
#   u'1',
#   u'0',
#   u'1',
#   u'1',
#   u'0',
#   u'0',
#   u'1',
#   u'-1'],
#  [u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'-1',
#   u'-1',
#   u'0',
#   u'1',
#   u'1',
#   u'1',
#   u'1',
#   u'0',
#   u'0',
#   u'-1',
#   u'1',
#   u'1',
#   u'0',
#   u'1',
#   u'0',
#   u'1',
#   u'0',
#   u'-1',
#   u'1',
#   u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'1',
#   u'1'],
#  [u'1',
#   u'-1',
#   u'1',
#   u'0',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'1',
#   u'1',
#   u'-1',
#   u'-1',
#   u'1',
#   u'-1',
#   u'1',
#   u'1',
#   u'0',
#   u'1',
#   u'0',
#   u'1',
#   u'0',
#   u'1',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'1',
#   u'1'],
#  [u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'1',
#   u'-1',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'0',
#   u'-1',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'1',
#   u'0',
#   u'-1',
#   u'0',
#   u'1',
#   u'0',
#   u'1'],
#  [u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'1',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'-1',
#   u'0',
#   u'-1',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'1',
#   u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'1'],
#  [u'0',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'0',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'0',
#   u'0',
#   u'1',
#   u'1',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'1',
#   u'-1'],
#  [u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'-1',
#   u'1',
#   u'0',
#   u'1',
#   u'0',
#   u'0',
#   u'-1',
#   u'0',
#   u'-1',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'0',
#   u'1',
#   u'1',
#   u'-1',
#   u'1',
#   u'1',
#   u'-1',
#   u'0',
#   u'-1',
#   u'0',
#   u'1'],
#  [u'0',
#   u'1',
#   u'0',
#   u'0',
#   u'1',
#   u'1',
#   u'1',
#   u'1',
#   u'-1',
#   u'1',
#   u'0',
#   u'0',
#   u'1',
#   u'1',
#   u'1',
#   u'1',
#   u'0',
#   u'0',
#   u'1',
#   u'1',
#   u'0',
#   u'1',
#   u'0',
#   u'1',
#   u'1',
#   u'1',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'-1'],
#  [u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'1',
#   u'0',
#   u'-1',
#   u'1',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'0',
#   u'1',
#   u'-1',
#   u'0',
#   u'0',
#   u'1',
#   u'-1'],
#  [u'0',
#   u'1',
#   u'0',
#   u'0',
#   u'1',
#   u'0',
#   u'-1',
#   u'-1',
#   u'-1',
#   u'1',
#   u'1',
#   u'0',
#   u'1',
#   u'-1',
#   u'-1',
#   u'1',
#   u'1',
#   u'1',
#   u'1',
#   u'1',
#   u'0',
#   u'1',
#   u'0',
#   u'-1',
#   u'1',
#   u'1',
#   u'0',
#   u'0',
#   u'-1',
#   u'1',
#   u'1'],
#  [u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'1',
#   u'-1',
#   u'0',
#   u'-1',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'1',
#   u'1',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'1'],
#  [u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'-1',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'-1',
#   u'1',
#   u'-1',
#   u'-1',
#   u'1',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'0',
#   u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'1',
#   u'-1'],
#  [u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'1',
#   u'0',
#   u'-1',
#   u'-1',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'-1',
#   u'-1',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'1',
#   u'-1',
#   u'0',
#   u'0',
#   u'-1',
#   u'0',
#   u'1'],
#  [u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'1',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'1',
#   u'0',
#   u'-1',
#   u'1',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'0',
#   u'1',
#   u'1',
#   u'0',
#   u'0',
#   u'1',
#   u'-1'],
#  [u'1',
#   u'-1',
#   u'1',
#   u'0',
#   u'1',
#   u'0',
#   u'1',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'1',
#   u'0',
#   u'-1',
#   u'-1',
#   u'1',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'1',
#   u'0',
#   u'-1',
#   u'1',
#   u'-1'],
#  [u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'0',
#   u'-1',
#   u'-1',
#   u'1',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'1'],
#  [u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'1',
#   u'1',
#   u'-1',
#   u'1',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'1',
#   u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'0',
#   u'1',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'-1'],
#  [u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'1',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'-1',
#   u'-1',
#   u'1',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'0',
#   u'-1',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'1'],
#  [u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'1',
#   u'-1',
#   u'1',
#   u'-1',
#   u'1',
#   u'0',
#   u'0',
#   u'1',
#   u'-1',
#   u'0',
#   u'-1',
#   u'-1',
#   u'0',
#   u'0',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'1',
#   u'1',
#   u'-1',
#   u'0',
#   u'1',
#   u'0',
#   u'1'],
#  [u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'1',
#   u'1',
#   u'0',
#   u'1',
#   u'1',
#   u'1',
#   u'1',
#   u'1',
#   u'-1',
#   u'0',
#   u'1',
#   u'-1',
#   u'1',
#   u'1',
#   u'1',
#   u'1',
#   u'0',
#   u'1',
#   u'0',
#   u'-1',
#   u'0',
#   u'1',
#   u'1',
#   u'0',
#   u'0',
#   u'1',
#   u'-1'],
#  [u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'1',
#   u'1',
#   u'1',
#   u'1',
#   u'0',
#   u'1',
#   u'1',
#   u'0',
#   u'1',
#   u'1',
#   u'-1',
#   u'-1',
#   u'1',
#   u'1',
#   u'1',
#   u'1',
#   u'0',
#   u'1',
#   u'0',
#   u'1',
#   u'1',
#   u'1',
#   u'1',
#   u'0',
#   u'1',
#   u'1',
#   u'-1'],
#  [u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'-1',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'-1',
#   u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'1',
#   u'-1',
#   u'-1',
#   u'0',
#   u'-1',
#   u'0',
#   u'1'],
#  [u'1',
#   u'-1',
#   u'1',
#   u'0',
#   u'1',
#   u'0',
#   u'-1',
#   u'1',
#   u'-1',
#   u'0',
#   u'0',
#   u'1',
#   u'1',
#   u'1',
#   u'0',
#   u'-1',
#   u'1',
#   u'1',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'1',
#   u'1',
#   u'-1',
#   u'0',
#   u'-1',
#   u'1',
#   u'-1'],
#  [u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'1',
#   u'0',
#   u'0',
#   u'-1',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'-1',
#   u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'1',
#   u'-1',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'1'],
#  [u'0',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'0',
#   u'1',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'1',
#   u'1',
#   u'1',
#   u'0',
#   u'-1',
#   u'0',
#   u'-1'],
#  [u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'-1',
#   u'1',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'0',
#   u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'1',
#   u'1',
#   u'-1',
#   u'0',
#   u'-1',
#   u'0',
#   u'-1'],
#  [u'0',
#   u'1',
#   u'0',
#   u'1',
#   u'0',
#   u'0',
#   u'1',
#   u'1',
#   u'-1',
#   u'0',
#   u'0',
#   u'1',
#   u'1',
#   u'0',
#   u'1',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'1',
#   u'1',
#   u'0',
#   u'0',
#   u'-1',
#   u'0',
#   u'-1'],
#  [u'0',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'1',
#   u'-1',
#   u'1',
#   u'0',
#   u'1',
#   u'1',
#   u'0',
#   u'0',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'0',
#   u'1',
#   u'0',
#   u'1',
#   u'0',
#   u'1',
#   u'-1',
#   u'0',
#   u'-1',
#   u'0',
#   u'-1'],
#  [u'1',
#   u'-1',
#   u'1',
#   u'0',
#   u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'-1',
#   u'-1',
#   u'1',
#   u'-1',
#   u'1',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'-1',
#   u'-1',
#   u'0',
#   u'0',
#   u'1',
#   u'1'],
#  [u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'1',
#   u'-1',
#   u'1',
#   u'-1',
#   u'-1',
#   u'1',
#   u'1',
#   u'1',
#   u'1',
#   u'0',
#   u'-1',
#   u'-1',
#   u'1',
#   u'1',
#   u'0',
#   u'1',
#   u'0',
#   u'1',
#   u'0',
#   u'1',
#   u'1',
#   u'0',
#   u'-1',
#   u'0',
#   u'-1',
#   u'1',
#   u'1'],
#  [u'0',
#   u'1',
#   u'0',
#   u'0',
#   u'1',
#   u'0',
#   u'-1',
#   u'1',
#   u'0',
#   u'1',
#   u'0',
#   u'1',
#   u'1',
#   u'0',
#   u'1',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'0',
#   u'1',
#   u'0',
#   u'1',
#   u'0',
#   u'1',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'-1'],
#  [u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'1',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'1',
#   u'1',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'0',
#   u'1',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'-1'],
#  [u'1',
#   u'1',
#   u'1',
#   u'0',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'1',
#   u'1',
#   u'-1',
#   u'0',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'1',
#   u'1',
#   u'-1',
#   u'0',
#   u'-1',
#   u'0',
#   u'1'],
#  [u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'1',
#   u'-1',
#   u'-1',
#   u'0',
#   u'0',
#   u'1',
#   u'1',
#   u'0',
#   u'1',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'0',
#   u'0',
#   u'-1',
#   u'0',
#   u'-1',
#   u'0',
#   u'1'],
#  [u'1',
#   u'-1',
#   u'1',
#   u'0',
#   u'1',
#   u'1',
#   u'1',
#   u'1',
#   u'1',
#   u'0',
#   u'0',
#   u'1',
#   u'-1',
#   u'1',
#   u'0',
#   u'-1',
#   u'1',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'0',
#   u'1',
#   u'1',
#   u'0',
#   u'1',
#   u'1',
#   u'-1'],
#  [u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'-1',
#   u'1',
#   u'0',
#   u'-1',
#   u'1',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'0',
#   u'-1',
#   u'-1',
#   u'0',
#   u'0',
#   u'1',
#   u'-1'],
#  [u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'-1',
#   u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'0',
#   u'-1',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'1'],
#  [u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'1',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'0',
#   u'1',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'0',
#   u'-1',
#   u'1',
#   u'0',
#   u'-1',
#   u'0',
#   u'-1'],
#  [u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'-1',
#   u'-1',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'-1',
#   u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'0',
#   u'-1',
#   u'-1',
#   u'0',
#   u'1',
#   u'0',
#   u'1'],
#  [u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'1',
#   u'1',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'0',
#   u'1',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'0',
#   u'-1',
#   u'0',
#   u'-1',
#   u'0',
#   u'1'],
#  [u'0',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'-1',
#   u'-1',
#   u'0',
#   u'0',
#   u'1',
#   u'1',
#   u'-1',
#   u'-1',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'1',
#   u'-1',
#   u'0',
#   u'0',
#   u'-1',
#   u'0',
#   u'1'],
#  [u'1',
#   u'-1',
#   u'1',
#   u'0',
#   u'1',
#   u'-1',
#   u'-1',
#   u'-1',
#   u'0',
#   u'1',
#   u'0',
#   u'1',
#   u'-1',
#   u'-1',
#   u'1',
#   u'-1',
#   u'1',
#   u'1',
#   u'1',
#   u'1',
#   u'0',
#   u'1',
#   u'0',
#   u'-1',
#   u'1',
#   u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'1',
#   u'1'],
#  [u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'1',
#   u'0',
#   u'1',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'-1'],
#  [u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'-1',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'1',
#   u'0',
#   u'-1',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'1',
#   u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'1'],
#  [u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'-1',
#   u'1',
#   u'0',
#   u'0',
#   u'1',
#   u'-1',
#   u'-1',
#   u'-1',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'1',
#   u'-1',
#   u'-1',
#   u'0',
#   u'1',
#   u'0',
#   u'1'],
#  [u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'0',
#   u'-1',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'1',
#   u'1',
#   u'1',
#   u'0',
#   u'1',
#   u'0',
#   u'-1'],
#  [u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'-1',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'-1',
#   u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'1',
#   u'-1',
#   u'0',
#   u'0',
#   u'1',
#   u'0',
#   u'1'],
#  [u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'1',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'0',
#   u'1',
#   u'-1',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'0',
#   u'1',
#   u'0',
#   u'0',
#   u'-1',
#   u'0',
#   u'-1'],
#  [u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'0',
#   u'0',
#   u'1'],
#  [u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'-1',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'0',
#   u'-1',
#   u'-1',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'1',
#   u'-1',
#   u'0',
#   u'-1',
#   u'0',
#   u'1'],
#  [u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'1',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'-1',
#   u'0',
#   u'-1',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'0',
#   u'-1',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'1'],
#  [u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'0',
#   u'1',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'0',
#   u'1',
#   u'-1',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'0',
#   u'1',
#   u'-1',
#   u'0',
#   u'-1',
#   u'0',
#   u'-1'],
#  [u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'-1',
#   u'-1',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'1',
#   u'-1',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'0',
#   u'-1',
#   u'-1',
#   u'0',
#   u'1',
#   u'0',
#   u'1'],
#  [u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'-1',
#   u'1',
#   u'1',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'1',
#   u'1',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'-1'],
#  [u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'-1',
#   u'-1',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'1',
#   u'-1',
#   u'0',
#   u'1',
#   u'0',
#   u'1'],
#  [u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'0',
#   u'-1',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'1'],
#  [u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'-1',
#   u'1',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'1',
#   u'1',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'0',
#   u'1',
#   u'-1',
#   u'0',
#   u'-1',
#   u'0',
#   u'-1'],
#  [u'0',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'-1',
#   u'1',
#   u'-1',
#   u'1',
#   u'0',
#   u'0',
#   u'1',
#   u'0',
#   u'1',
#   u'1',
#   u'0',
#   u'1',
#   u'0',
#   u'1',
#   u'0',
#   u'1',
#   u'0',
#   u'-1',
#   u'1',
#   u'0',
#   u'-1',
#   u'0',
#   u'-1',
#   u'1',
#   u'1'],
#  [u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'0',
#   u'1',
#   u'-1',
#   u'1',
#   u'0',
#   u'0',
#   u'1',
#   u'0',
#   u'0',
#   u'-1',
#   u'1',
#   u'1',
#   u'0',
#   u'1',
#   u'0',
#   u'1',
#   u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'-1',
#   u'0',
#   u'-1',
#   u'1',
#   u'-1'],
#  [u'1',
#   u'1',
#   u'1',
#   u'0',
#   u'1',
#   u'-1',
#   u'1',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'1',
#   u'-1',
#   u'1',
#   u'1',
#   u'0',
#   u'1',
#   u'1',
#   u'1',
#   u'0',
#   u'1',
#   u'0',
#   u'1',
#   u'0',
#   u'1',
#   u'-1',
#   u'0',
#   u'0',
#   u'1',
#   u'1'],
#  [u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'-1',
#   u'-1',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'-1',
#   u'0',
#   u'1',
#   u'0',
#   u'1'],
#  [u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'1',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'0',
#   u'-1',
#   u'-1',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'-1'],
#  [u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'1',
#   u'1',
#   u'0',
#   u'1',
#   u'1',
#   u'0',
#   u'1',
#   u'1',
#   u'-1',
#   u'-1',
#   u'1',
#   u'0',
#   u'0',
#   u'1',
#   u'0',
#   u'1',
#   u'0',
#   u'1',
#   u'0',
#   u'1',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'-1'],
#  [u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'-1',
#   u'1',
#   u'0',
#   u'0',
#   u'1',
#   u'-1',
#   u'0',
#   u'-1',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'-1',
#   u'0',
#   u'1',
#   u'0',
#   u'-1'],
#  [u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'0',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'1',
#   u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'0',
#   u'1',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'-1'],
#  [u'0',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'0',
#   u'-1',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'0',
#   u'0',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'-1',
#   u'0',
#   u'-1',
#   u'0',
#   u'-1'],
#  [u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'0',
#   u'-1',
#   u'-1',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'-1'],
#  [u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'-1',
#   u'-1',
#   u'1',
#   u'1',
#   u'0',
#   u'0',
#   u'-1',
#   u'-1',
#   u'1',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'0',
#   u'1',
#   u'0',
#   u'-1',
#   u'1',
#   u'-1',
#   u'-1',
#   u'0',
#   u'1',
#   u'0',
#   u'1'],
#  [u'0',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'-1',
#   u'1',
#   u'1',
#   u'0',
#   u'1',
#   u'0',
#   u'-1',
#   u'1',
#   u'1',
#   u'0',
#   u'0',
#   u'1',
#   u'0',
#   u'1',
#   u'1',
#   u'-1',
#   u'1',
#   u'1',
#   u'-1',
#   u'0',
#   u'-1',
#   u'0',
#   u'-1'],
#  [u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'0',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'0',
#   u'1',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'0',
#   u'1',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'-1'],
#  [u'0',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'1',
#   u'-1',
#   u'1',
#   u'0',
#   u'0',
#   u'1',
#   u'0',
#   u'0',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'0',
#   u'1',
#   u'0',
#   u'1',
#   u'1',
#   u'1',
#   u'0',
#   u'0',
#   u'-1',
#   u'0',
#   u'-1'],
#  [u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'0',
#   u'-1',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'0',
#   u'-1',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'-1',
#   u'0',
#   u'1',
#   u'0',
#   u'-1'],
#  [u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'1',
#   u'0',
#   u'-1',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'0',
#   u'-1',
#   u'-1',
#   u'0',
#   u'0',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'1',
#   u'1',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'1'],
#  [u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'1',
#   u'-1',
#   u'-1',
#   u'0',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'0',
#   u'-1',
#   u'-1',
#   u'0',
#   u'0',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'1',
#   u'0',
#   u'-1',
#   u'0',
#   u'1',
#   u'0',
#   u'1'],
#  [u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'1',
#   u'1',
#   u'0',
#   u'0',
#   u'1',
#   u'-1',
#   u'1',
#   u'1',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'0',
#   u'1',
#   u'0',
#   u'0',
#   u'1',
#   u'0',
#   u'-1'],
#  [u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'1',
#   u'-1',
#   u'1',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'0',
#   u'0',
#   u'-1',
#   u'1',
#   u'0',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'1',
#   u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'1'],
#  [u'1',
#   u'-1',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'1',
#   u'1',
#   u'0',
#   u'0',
#   u'1',
#   u'-1',
#   u'0',
#   u'-1',
#   u'-1',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'1',
#   u'1',
#   u'0',
#   u'0',
#   u'1',
#   u'0',
#   u'-1'],
#  [u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'-1',
#   u'-1',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'1',
#   u'-1',
#   u'0',
#   u'0',
#   u'1',
#   u'0',
#   u'1'],
#  [u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'1',
#   u'-1',
#   u'1',
#   u'1',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'1',
#   u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'0',
#   u'1',
#   u'1',
#   u'0',
#   u'-1',
#   u'0',
#   u'-1'],
#  [u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'-1',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'0',
#   u'-1',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'1',
#   u'1',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'1'],
#  [u'1',
#   u'-1',
#   u'1',
#   u'0',
#   u'0',
#   u'1',
#   u'1',
#   u'1',
#   u'-1',
#   u'0',
#   u'0',
#   u'1',
#   u'1',
#   u'0',
#   u'-1',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'1',
#   u'1',
#   u'-1',
#   u'0',
#   u'-1',
#   u'0',
#   u'-1'],
#  [u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'-1',
#   u'-1',
#   u'-1',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'1',
#   u'-1',
#   u'-1',
#   u'0',
#   u'1',
#   u'0',
#   u'1'],
#  [u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'1',
#   u'-1',
#   u'-1',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'-1',
#   u'0',
#   u'-1',
#   u'-1',
#   u'0',
#   u'0',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'1',
#   u'1',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'1'],
#  [u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'-1',
#   u'1',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'0',
#   u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'1',
#   u'0',
#   u'-1',
#   u'0',
#   u'-1',
#   u'0',
#   u'1'],
#  [u'0',
#   u'1',
#   u'0',
#   u'1',
#   u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'-1',
#   u'0',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'-1',
#   u'-1',
#   u'0',
#   u'-1',
#   u'0',
#   u'1'],
#  [u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'1',
#   u'-1',
#   u'-1',
#   u'1',
#   u'0',
#   u'0',
#   u'1',
#   u'0',
#   u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'0',
#   u'1',
#   u'0',
#   u'1',
#   u'1',
#   u'0',
#   u'-1',
#   u'0',
#   u'-1',
#   u'0',
#   u'1'],
#  [u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'-1',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'0',
#   u'-1',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'1',
#   u'0',
#   u'-1',
#   u'0',
#   u'1',
#   u'0',
#   u'1'],
#  [u'0',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'-1',
#   u'-1',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'-1',
#   u'0',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'1',
#   u'0',
#   u'-1',
#   u'0',
#   u'1',
#   u'0',
#   u'1'],
#  [u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'-1',
#   u'1',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'0',
#   u'-1',
#   u'-1',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'1',
#   u'0',
#   u'-1',
#   u'0',
#   u'1',
#   u'0',
#   u'1'],
#  [u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'-1',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'-1',
#   u'0',
#   u'-1',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'1',
#   u'1',
#   u'0',
#   u'0',
#   u'-1',
#   u'0',
#   u'1'],
#  [u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'0',
#   u'1',
#   u'-1',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'1',
#   u'-1',
#   u'-1',
#   u'0',
#   u'1',
#   u'0',
#   u'-1'],
#  [u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'-1',
#   u'1',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'0',
#   u'0',
#   u'-1',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'1',
#   u'1',
#   u'-1',
#   u'0',
#   u'-1',
#   u'0',
#   u'-1'],
#  [u'0',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'1',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'0',
#   u'-1',
#   u'1',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'1',
#   u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'-1'],
#  [u'1',
#   u'1',
#   u'1',
#   u'0',
#   u'1',
#   u'-1',
#   u'-1',
#   u'1',
#   u'-1',
#   u'0',
#   u'0',
#   u'1',
#   u'1',
#   u'1',
#   u'-1',
#   u'1',
#   u'0',
#   u'0',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'1',
#   u'1',
#   u'1',
#   u'0',
#   u'-1',
#   u'0',
#   u'-1'],
#  [u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'1',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'0',
#   u'-1',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'1',
#   u'1',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'-1'],
#  [u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'1',
#   u'-1',
#   u'1',
#   u'0',
#   u'1',
#   u'1',
#   u'1',
#   u'-1',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'0',
#   u'1',
#   u'0',
#   u'1',
#   u'1',
#   u'1',
#   u'-1',
#   u'0',
#   u'-1',
#   u'0',
#   u'-1'],
#  [u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'-1',
#   u'1',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'-1',
#   u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'0',
#   u'1',
#   u'-1',
#   u'0',
#   u'-1',
#   u'0',
#   u'-1'],
#  [u'0',
#   u'-1',
#   u'0',
#   u'1',
#   u'0',
#   u'0',
#   u'-1',
#   u'-1',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'-1',
#   u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'1',
#   u'-1',
#   u'0',
#   u'0',
#   u'1',
#   u'0',
#   u'1'],
#  [u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'1',
#   u'1',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'0',
#   u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'0',
#   u'-1',
#   u'0',
#   u'-1'],
#  [u'1',
#   u'-1',
#   u'1',
#   u'0',
#   u'1',
#   u'-1',
#   u'-1',
#   u'-1',
#   u'-1',
#   u'1',
#   u'0',
#   u'1',
#   u'1',
#   u'-1',
#   u'1',
#   u'-1',
#   u'0',
#   u'0',
#   u'1',
#   u'1',
#   u'0',
#   u'1',
#   u'0',
#   u'-1',
#   u'1',
#   u'1',
#   u'-1',
#   u'0',
#   u'-1',
#   u'0',
#   u'1'],
#  [u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'-1',
#   u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'-1',
#   u'-1',
#   u'0',
#   u'-1',
#   u'0',
#   u'1'],
#  [u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'1',
#   u'1',
#   u'0',
#   u'0',
#   u'-1',
#   u'0',
#   u'-1',
#   u'-1',
#   u'1',
#   u'0',
#   u'0',
#   u'1',
#   u'0',
#   u'1',
#   u'0',
#   u'-1',
#   u'1',
#   u'1',
#   u'0',
#   u'0',
#   u'1',
#   u'0',
#   u'-1'],
#  [u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'0',
#   u'1',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'0',
#   u'-1',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'1',
#   u'1',
#   u'-1',
#   u'0',
#   u'-1',
#   u'0',
#   u'-1'],
#  [u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'1',
#   u'0',
#   u'1',
#   u'0',
#   u'0',
#   u'1',
#   u'0',
#   u'-1',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'0',
#   u'1',
#   u'0',
#   u'1',
#   u'1',
#   u'1',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'-1'],
#  [u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'1',
#   u'1',
#   u'-1',
#   u'0',
#   u'0',
#   u'1',
#   u'1',
#   u'0',
#   u'1',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'0',
#   u'0',
#   u'-1',
#   u'0',
#   u'-1',
#   u'0',
#   u'-1'],
#  [u'1',
#   u'-1',
#   u'1',
#   u'0',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'-1',
#   u'-1',
#   u'1',
#   u'-1',
#   u'0',
#   u'0',
#   u'1',
#   u'1',
#   u'0',
#   u'1',
#   u'0',
#   u'1',
#   u'1',
#   u'-1',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'1'],
#  [u'0',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'-1',
#   u'1',
#   u'-1',
#   u'0',
#   u'0',
#   u'1',
#   u'1',
#   u'0',
#   u'0',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'0',
#   u'1',
#   u'1',
#   u'0',
#   u'-1',
#   u'0',
#   u'-1'],
#  [u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'1',
#   u'1',
#   u'0',
#   u'1',
#   u'-1',
#   u'-1',
#   u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'0',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'-1',
#   u'0',
#   u'1',
#   u'0',
#   u'1'],
#  [u'0',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'-1',
#   u'1',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'1',
#   u'-1',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'1',
#   u'1',
#   u'1',
#   u'0',
#   u'-1',
#   u'0',
#   u'-1'],
#  [u'1',
#   u'-1',
#   u'1',
#   u'0',
#   u'1',
#   u'0',
#   u'-1',
#   u'1',
#   u'1',
#   u'0',
#   u'0',
#   u'1',
#   u'-1',
#   u'0',
#   u'1',
#   u'-1',
#   u'0',
#   u'0',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'1',
#   u'1',
#   u'-1',
#   u'0',
#   u'1',
#   u'0',
#   u'-1'],
#  [u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'1',
#   u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'0',
#   u'1',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'-1'],
#  [u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'-1',
#   u'1',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'-1',
#   u'-1',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'-1',
#   u'1',
#   u'1',
#   u'0',
#   u'1'],
#  [u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'0',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'0',
#   u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'-1'],
#  [u'1',
#   u'-1',
#   u'1',
#   u'0',
#   u'1',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'0',
#   u'1',
#   u'1',
#   u'-1',
#   u'1',
#   u'-1',
#   u'0',
#   u'1',
#   u'0',
#   u'1',
#   u'0',
#   u'1',
#   u'0',
#   u'0',
#   u'1',
#   u'1',
#   u'-1',
#   u'0',
#   u'0',
#   u'1',
#   u'1'],
#  [u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'1',
#   u'-1',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'0',
#   u'0',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'-1'],
#  [u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'-1',
#   u'1',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'0',
#   u'-1',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'1',
#   u'1',
#   u'-1',
#   u'0',
#   u'1',
#   u'0',
#   u'-1'],
#  [u'1',
#   u'-1',
#   u'1',
#   u'0',
#   u'1',
#   u'1',
#   u'-1',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'-1',
#   u'0',
#   u'0',
#   u'-1',
#   u'0',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'1',
#   u'1',
#   u'-1',
#   u'0',
#   u'0',
#   u'1',
#   u'-1'],
#  [u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'0',
#   u'1',
#   u'1',
#   u'0',
#   u'0',
#   u'1',
#   u'-1',
#   u'0',
#   u'-1',
#   u'-1',
#   u'0',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'-1',
#   u'0',
#   u'1',
#   u'1',
#   u'1'],
#  [u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'-1',
#   u'1',
#   u'-1',
#   u'1',
#   u'0',
#   u'1',
#   u'1',
#   u'1',
#   u'1',
#   u'-1',
#   u'0',
#   u'1',
#   u'0',
#   u'1',
#   u'0',
#   u'1',
#   u'0',
#   u'1',
#   u'1',
#   u'1',
#   u'-1',
#   u'0',
#   u'-1',
#   u'1',
#   u'-1'],
#  [u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'-1',
#   u'-1',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'0',
#   u'1',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'-1',
#   u'0',
#   u'1',
#   u'0',
#   u'1'],
#  [u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'0',
#   u'-1',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'0',
#   u'-1',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'0',
#   u'1',
#   u'-1',
#   u'0',
#   u'1',
#   u'0',
#   u'1'],
#  [u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'0',
#   u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'0',
#   u'1',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'-1'],
#  [u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'0',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'1',
#   u'-1',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'-1'],
#  [u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'0',
#   u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'0',
#   u'1',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'-1'],
#  [u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'-1',
#   u'1',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'0',
#   u'-1',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'1',
#   u'-1',
#   u'-1',
#   u'0',
#   u'1',
#   u'0',
#   u'-1'],
#  [u'1',
#   u'-1',
#   u'1',
#   u'0',
#   u'1',
#   u'0',
#   u'1',
#   u'1',
#   u'-1',
#   u'0',
#   u'0',
#   u'1',
#   u'1',
#   u'0',
#   u'0',
#   u'-1',
#   u'0',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'1',
#   u'1',
#   u'-1',
#   u'0',
#   u'-1',
#   u'1',
#   u'-1'],
#  [u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'-1',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'0',
#   u'-1',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'1'],
#  [u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'1',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'0',
#   u'1',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'0',
#   u'1',
#   u'0',
#   u'0',
#   u'1',
#   u'0',
#   u'-1'],
#  [u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'-1',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'1'],
#  [u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'0',
#   u'1',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'1',
#   u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'-1',
#   u'0',
#   u'-1',
#   u'0',
#   u'-1'],
#  [u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'1',
#   u'1',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'0',
#   u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'0',
#   u'-1',
#   u'1',
#   u'1',
#   u'0',
#   u'1'],
#  [u'1',
#   u'-1',
#   u'1',
#   u'0',
#   u'1',
#   u'-1',
#   u'0',
#   u'-1',
#   u'1',
#   u'1',
#   u'0',
#   u'1',
#   u'-1',
#   u'-1',
#   u'1',
#   u'-1',
#   u'0',
#   u'1',
#   u'0',
#   u'1',
#   u'0',
#   u'1',
#   u'1',
#   u'-1',
#   u'1',
#   u'1',
#   u'-1',
#   u'1',
#   u'1',
#   u'1',
#   u'1'],
#  [u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'0',
#   u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'1',
#   u'0',
#   u'0',
#   u'1',
#   u'0',
#   u'-1'],
#  [u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'1',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'0',
#   u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'0',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'-1'],
#  [u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'0',
#   u'-1',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'1',
#   u'-1',
#   u'0',
#   u'0',
#   u'1',
#   u'0',
#   u'1'],
#  [u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'1',
#   u'1',
#   u'-1',
#   u'1',
#   u'1',
#   u'0',
#   u'1',
#   u'0',
#   u'0',
#   u'-1',
#   u'1',
#   u'0',
#   u'0',
#   u'1',
#   u'0',
#   u'1',
#   u'0',
#   u'1',
#   u'1',
#   u'1',
#   u'-1',
#   u'0',
#   u'1',
#   u'0',
#   u'-1'],
#  [u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'-1',
#   u'1',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'0',
#   u'1',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'1'],
#  [u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'-1',
#   u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'1',
#   u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'1'],
#  [u'1',
#   u'-1',
#   u'1',
#   u'0',
#   u'1',
#   u'0',
#   u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'1',
#   u'0',
#   u'0',
#   u'-1',
#   u'0',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'1',
#   u'0',
#   u'0',
#   u'1',
#   u'1',
#   u'-1'],
#  [u'0',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'0',
#   u'-1',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'1',
#   u'1',
#   u'-1',
#   u'0',
#   u'1',
#   u'0',
#   u'-1'],
#  [u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'-1',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'-1',
#   u'1',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'1',
#   u'-1',
#   u'-1',
#   u'0',
#   u'1',
#   u'0',
#   u'1'],
#  [u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'-1',
#   u'0',
#   u'-1',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'1',
#   u'-1',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'1'],
#  [u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'1',
#   u'1',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'0',
#   u'0',
#   u'-1',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'1',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'-1'],
#  [u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'-1',
#   u'-1',
#   u'-1',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'1',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1'],
#  [u'0',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'-1',
#   u'1',
#   u'0',
#   u'0',
#   u'1',
#   u'0',
#   u'0',
#   u'1',
#   u'1',
#   u'0',
#   u'0',
#   u'1',
#   u'0',
#   u'1',
#   u'0',
#   u'-1',
#   u'1',
#   u'1',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'-1'],
#  [u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'0',
#   u'1',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'0',
#   u'1',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'-1'],
#  [u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'-1',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'0',
#   u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'0',
#   u'1',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'-1'],
#  [u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'-1',
#   u'0',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'0',
#   u'-1',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'0',
#   u'1',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'1'],
#  [u'1',
#   u'1',
#   u'1',
#   u'0',
#   u'1',
#   u'-1',
#   u'0',
#   u'-1',
#   u'0',
#   u'1',
#   u'0',
#   u'1',
#   u'1',
#   u'-1',
#   u'1',
#   u'1',
#   u'0',
#   u'1',
#   u'0',
#   u'1',
#   u'0',
#   u'1',
#   u'0',
#   u'-1',
#   u'1',
#   u'1',
#   u'-1',
#   u'0',
#   u'1',
#   u'1',
#   u'1'],
#  [u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'1',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'1',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'-1'],
#  [u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'1',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'0',
#   u'1',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'1',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'-1'],
#  [u'0',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'1',
#   u'-1',
#   u'0',
#   u'0',
#   u'1',
#   u'1',
#   u'0',
#   u'0',
#   u'1',
#   u'0',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'-1',
#   u'0',
#   u'0',
#   u'1',
#   u'-1'],
#  [u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'-1',
#   u'-1',
#   u'1',
#   u'0',
#   u'0',
#   u'1',
#   u'-1',
#   u'-1',
#   u'0',
#   u'-1',
#   u'0',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'1',
#   u'-1',
#   u'-1',
#   u'0',
#   u'1',
#   u'1',
#   u'1'],
#  [u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'1',
#   u'0',
#   u'0',
#   u'1',
#   u'-1',
#   u'0',
#   u'0',
#   u'-1',
#   u'0',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'0',
#   u'1',
#   u'-1',
#   u'0',
#   u'0',
#   u'1',
#   u'-1'],
#  [u'1',
#   u'-1',
#   u'1',
#   u'0',
#   u'1',
#   u'-1',
#   u'0',
#   u'1',
#   u'1',
#   u'0',
#   u'0',
#   u'1',
#   u'-1',
#   u'1',
#   u'-1',
#   u'-1',
#   u'0',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'1',
#   u'1',
#   u'1',
#   u'0',
#   u'1',
#   u'1',
#   u'-1'],
#  [u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'-1',
#   u'-1',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'0',
#   u'1',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
# ...
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'0',
#   u'-1',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'1',
#   u'-1',
#   u'1',
#   u'1',
#   u'0',
#   u'1'],
#  [u'1',
#   u'1',
#   u'1',
#   u'0',
#   u'1',
#   u'-1',
#   u'0',
#   u'-1',
#   u'-1',
#   u'1',
#   u'1',
#   u'1',
#   u'1',
#   u'-1',
#   u'1',
#   u'1',
#   u'1',
#   u'1',
#   u'1',
#   u'1',
#   u'1',
#   u'1',
#   u'1',
#   u'-1',
#   u'1',
#   u'1',
#   u'-1',
#   u'0',
#   u'1',
#   u'1',
#   u'1'],
#  [u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'-1',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'0',
#   u'-1',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'-1'],
#  [u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'1',
#   u'1',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'0',
#   u'1',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'-1'],
#  [u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'-1',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'0',
#   u'-1',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'1',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'1'],
#  [u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'-1',
#   u'-1',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'1',
#   u'1',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'1'],
#  [u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'-1',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'-1',
#   u'-1',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'1',
#   u'0',
#   u'-1',
#   u'0',
#   u'1',
#   u'0',
#   u'1'],
#  [u'1',
#   u'1',
#   u'1',
#   u'0',
#   u'1',
#   u'-1',
#   u'1',
#   u'1',
#   u'-1',
#   u'0',
#   u'0',
#   u'1',
#   u'1',
#   u'0',
#   u'-1',
#   u'1',
#   u'0',
#   u'1',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'1',
#   u'0',
#   u'-1',
#   u'0',
#   u'1',
#   u'0',
#   u'1'],
#  [u'0',
#   u'-1',
#   u'0',
#   u'1',
#   u'0',
#   u'-1',
#   u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'-1',
#   u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'0',
#   u'-1',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'1'],
#  [u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'1',
#   u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'0',
#   u'1',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'-1'],
#  [u'0',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'-1',
#   u'0',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'1',
#   u'0',
#   u'-1',
#   u'0',
#   u'1',
#   u'0',
#   u'1'],
#  [u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'1',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'0',
#   u'1',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'0',
#   u'0',
#   u'-1',
#   u'1',
#   u'0',
#   u'0',
#   u'1'],
#  [u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'-1',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'-1',
#   u'1',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'1',
#   u'-1',
#   u'-1',
#   u'1',
#   u'1',
#   u'0',
#   u'1'],
#  [u'1',
#   u'-1',
#   u'1',
#   u'0',
#   u'1',
#   u'1',
#   u'1',
#   u'-1',
#   u'-1',
#   u'0',
#   u'0',
#   u'1',
#   u'1',
#   u'1',
#   u'0',
#   u'-1',
#   u'0',
#   u'1',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'1',
#   u'1',
#   u'-1',
#   u'1',
#   u'1',
#   u'0',
#   u'-1'],
#  [u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'1',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'1',
#   u'0',
#   u'1',
#   u'1',
#   u'0',
#   u'0',
#   u'-1'],
#  [u'0',
#   u'-1',
#   u'0',
#   u'1',
#   u'0',
#   u'0',
#   u'-1',
#   u'1',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'1',
#   u'1',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'1',
#   u'1',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'-1'],
#  [u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'1',
#   u'1',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'1',
#   u'1',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'1',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'-1'],
#  [u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'0',
#   u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'0',
#   u'1',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'-1'],
#  [u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'1',
#   u'0',
#   u'1',
#   u'1',
#   u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'-1',
#   u'1',
#   u'0',
#   u'0',
#   u'1',
#   u'1',
#   u'1',
#   u'1',
#   u'1',
#   u'1',
#   u'1',
#   u'0',
#   u'0',
#   u'1',
#   u'1',
#   u'-1'],
#  [u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'-1',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'-1',
#   u'-1',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'1',
#   u'1',
#   u'-1',
#   u'0',
#   u'1',
#   u'0',
#   u'-1'],
#  [u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'-1',
#   u'1',
#   u'1',
#   u'0',
#   u'1',
#   u'0',
#   u'1',
#   u'-1',
#   u'1',
#   u'0',
#   u'0',
#   u'1',
#   u'1',
#   u'1',
#   u'1',
#   u'-1',
#   u'1',
#   u'1',
#   u'0',
#   u'0',
#   u'1',
#   u'1',
#   u'-1'],
#  [u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'-1',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'-1',
#   u'-1',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'0',
#   u'-1',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'1'],
#  [u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'0',
#   u'-1',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'0',
#   u'-1',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'1'],
#  [u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'-1',
#   u'1',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'1',
#   u'-1',
#   u'-1',
#   u'0',
#   u'1',
#   u'0',
#   u'1'],
#  [u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'1',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'0',
#   u'1',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'-1'],
#  [u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'-1',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'-1',
#   u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'1',
#   u'1',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'1'],
#  [u'1',
#   u'-1',
#   u'1',
#   u'0',
#   u'1',
#   u'0',
#   u'-1',
#   u'1',
#   u'-1',
#   u'0',
#   u'0',
#   u'1',
#   u'1',
#   u'1',
#   u'1',
#   u'-1',
#   u'0',
#   u'1',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'0',
#   u'1',
#   u'-1',
#   u'0',
#   u'1',
#   u'0',
#   u'-1'],
#  [u'1',
#   u'1',
#   u'1',
#   u'0',
#   u'1',
#   u'-1',
#   u'1',
#   u'1',
#   u'-1',
#   u'0',
#   u'0',
#   u'1',
#   u'1',
#   u'0',
#   u'-1',
#   u'1',
#   u'0',
#   u'1',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'0',
#   u'0',
#   u'-1',
#   u'0',
#   u'1',
#   u'0',
#   u'-1'],
#  [u'1',
#   u'-1',
#   u'1',
#   u'0',
#   u'1',
#   u'0',
#   u'1',
#   u'1',
#   u'-1',
#   u'0',
#   u'0',
#   u'1',
#   u'1',
#   u'1',
#   u'0',
#   u'-1',
#   u'0',
#   u'1',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'1',
#   u'1',
#   u'-1',
#   u'0',
#   u'1',
#   u'0',
#   u'-1'],
#  [u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'1',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'-1'],
#  [u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'0',
#   u'-1',
#   u'0',
#   u'1',
#   u'1',
#   u'0',
#   u'1',
#   u'-1',
#   u'0',
#   u'-1',
#   u'1',
#   u'0',
#   u'0',
#   u'1',
#   u'1',
#   u'1',
#   u'1',
#   u'-1',
#   u'1',
#   u'1',
#   u'-1',
#   u'0',
#   u'0',
#   u'1',
#   u'1'],
#  [u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'-1',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'-1',
#   u'-1',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'1',
#   u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'1'],
#  [u'1',
#   u'-1',
#   u'1',
#   u'0',
#   u'1',
#   u'1',
#   u'-1',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'1',
#   u'0',
#   u'0',
#   u'-1',
#   u'0',
#   u'1',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'1',
#   u'1',
#   u'-1',
#   u'0',
#   u'1',
#   u'0',
#   u'-1'],
#  [u'1',
#   u'1',
#   u'1',
#   u'0',
#   u'1',
#   u'0',
#   u'-1',
#   u'-1',
#   u'1',
#   u'1',
#   u'1',
#   u'1',
#   u'-1',
#   u'-1',
#   u'1',
#   u'1',
#   u'1',
#   u'1',
#   u'1',
#   u'1',
#   u'1',
#   u'1',
#   u'1',
#   u'-1',
#   u'1',
#   u'-1',
#   u'0',
#   u'0',
#   u'1',
#   u'1',
#   u'1'],
#  [u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'0',
#   u'1',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'1',
#   u'-1',
#   u'1',
#   u'0',
#   u'1',
#   u'0',
#   u'-1'],
#  [u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'1',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'0',
#   u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'0',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'-1'],
#  [u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'1',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'0',
#   u'-1',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'0',
#   u'1',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'-1'],
#  [u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'0',
#   u'-1',
#   u'0',
#   u'1',
#   u'1',
#   u'0',
#   u'1',
#   u'-1',
#   u'1',
#   u'-1',
#   u'1',
#   u'0',
#   u'0',
#   u'1',
#   u'1',
#   u'1',
#   u'1',
#   u'-1',
#   u'1',
#   u'-1',
#   u'-1',
#   u'0',
#   u'0',
#   u'1',
#   u'1'],
#  [u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'-1',
#   u'1',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'1',
#   u'1',
#   u'-1',
#   u'1',
#   u'0',
#   u'0',
#   u'1'],
#  [u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'1',
#   u'0',
#   u'1',
#   u'-1',
#   u'-1',
#   u'-1',
#   u'1',
#   u'0',
#   u'0',
#   u'1',
#   u'1',
#   u'1',
#   u'1',
#   u'0',
#   u'1',
#   u'1',
#   u'-1',
#   u'0',
#   u'0',
#   u'1',
#   u'1'],
#  [u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'0',
#   u'-1',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'0',
#   u'1',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'-1'],
#  [u'1',
#   u'1',
#   u'0',
#   u'0',
#   u'1',
#   u'-1',
#   u'-1',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'1',
#   u'-1',
#   u'1',
#   u'-1',
#   u'1',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'1',
#   u'-1',
#   u'-1',
#   u'0',
#   u'1',
#   u'1',
#   u'1'],
#  [u'0',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'0',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'1',
#   u'0',
#   u'-1',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'1',
#   u'0',
#   u'-1',
#   u'0',
#   u'1',
#   u'0',
#   u'1'],
#  [u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'-1',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'1',
#   u'0',
#   u'-1',
#   u'-1',
#   u'1',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'1',
#   u'-1',
#   u'0',
#   u'0',
#   u'1',
#   u'1'],
#  [u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'-1',
#   u'-1',
#   u'1',
#   u'0',
#   u'0',
#   u'1',
#   u'-1',
#   u'0',
#   u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'0',
#   u'1',
#   u'-1',
#   u'1',
#   u'-1',
#   u'0',
#   u'1'],
#  [u'0',
#   u'0',
#   u'1',
#   u'0',
#   u'0',
#   u'-1',
#   u'1',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'0',
#   u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'0',
#   u'1',
#   u'0',
#   u'-1',
#   u'1',
#   u'0',
#   u'-1',
#   u'0',
#   u'1',
#   u'0',
#   u'-1'],
#  [u'1',
#   u'0',
#   u'1',
#   u'0',
#   u'1',
#   u'0',
#   u'1',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'1',
#   u'0',
#   u'0',
#   u'-1',
#   u'1',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'1',
#   u'0',
#   u'0',
#   u'-1',
#   u'1',
#   u'-1'],
#  [u'0',
#   u'0',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'-1',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'-1',
#   u'0',
#   u'-1',
#   u'1',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'1',
#   u'-1',
#   u'-1',
#   u'0',
#   u'0',
#   u'1',
#   u'1'],
#  [u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'-1',
#   u'-1',
#   u'1',
#   u'0',
#   u'0',
#   u'1',
#   u'-1',
#   u'0',
#   u'-1',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'-1',
#   u'1',
#   u'0',
#   u'0',
#   u'1'],
#  [u'0',
#   u'0',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'1',
#   u'-1',
#   u'0',
#   u'0',
#   u'1',
#   u'1',
#   u'0',
#   u'1',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'1',
#   u'1',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'-1'],
#  [u'0',
#   u'1',
#   u'1',
#   u'0',
#   u'0',
#   u'-1',
#   u'-1',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'0',
#   u'1',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'1',
#   u'0',
#   u'-1',
#   u'1',
#   u'0',
#   u'0',
#   u'1'],
#  [u'0',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'-1',
#   u'1',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'0',
#   u'1',
#   u'1',
#   u'0',
#   u'-1',
#   u'1',
#   u'-1'],
#  [u'0',
#   u'1',
#   u'1',
#   u'0',
#   u'0',
#   u'-1',
#   u'1',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'-1',
#   u'-1',
#   u'-1',
#   u'1',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'1',
#   u'-1',
#   u'-1',
#   u'1',
#   u'0',
#   u'1',
#   u'1'],
#  [u'1',
#   u'1',
#   u'1',
#   u'0',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'0',
#   u'0',
#   u'1',
#   u'-1',
#   u'-1',
#   u'1',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'0',
#   u'1',
#   u'0',
#   u'0',
#   u'1',
#   u'-1',
#   u'-1',
#   u'1',
#   u'0',
#   u'0',
#   u'1'],
#  [u'0',
#   u'1',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'-1',
#   u'-1',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'1',
#   u'0',
#   u'-1',
#   u'1',
#   u'1',
#   u'0',
#   u'1'],
#  [u'0',
#   u'1',
#   u'1',
#   u'0',
#   u'0',
#   u'1',
#   u'-1',
#   u'1',
#   u'-1',
#   u'0',
#   u'0',
#   u'1',
#   u'1',
#   u'0',
#   u'1',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'0',
#   u'1',
#   u'-1',
#   u'0',
#   u'-1',
#   u'0',
#   u'-1'],
#  [u'0',
#   u'-1',
#   u'1',
#   u'1',
#   u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'-1',
#   u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'1',
#   u'-1',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'1'],
#  [u'0',
#   u'-1',
#   u'1',
#   u'0',
#   u'0',
#   u'-1',
#   u'1',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'1',
#   u'0',
#   u'-1',
#   u'-1',
#   u'1',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'0',
#   u'-1',
#   u'0',
#   u'1',
#   u'1',
#   u'1'],
#  [u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'-1',
#   u'0',
#   u'1',
#   u'0',
#   u'1',
#   u'0',
#   u'1',
#   u'0',
#   u'-1',
#   u'-1',
#   u'1',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'0',
#   u'1',
#   u'-1',
#   u'0',
#   u'1',
#   u'1',
#   u'1'],
#  [u'0',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'1',
#   u'1',
#   u'0',
#   u'0',
#   u'1',
#   u'-1',
#   u'0',
#   u'-1',
#   u'-1',
#   u'1',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'0',
#   u'-1',
#   u'1',
#   u'0',
#   u'-1',
#   u'1',
#   u'-1'],
#  [u'0',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'-1',
#   u'1',
#   u'-1',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'0',
#   u'0',
#   u'-1',
#   u'1',
#   u'1',
#   u'0',
#   u'1',
#   u'1',
#   u'1',
#   u'1',
#   u'1',
#   u'0',
#   u'0',
#   u'-1',
#   u'0',
#   u'0',
#   u'1',
#   u'-1'],
#  [u'0',
#   u'0',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'0',
#   u'0',
#   u'-1',
#   u'1',
#   u'1',
#   u'0',
#   u'1',
#   u'0',
#   u'1',
#   u'0',
#   u'-1',
#   u'1',
#   u'1',
#   u'-1',
#   u'1',
#   u'-1',
#   u'1',
#   u'-1'],
#  [u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'1',
#   u'1',
#   u'0',
#   u'0',
#   u'1',
#   u'-1',
#   u'0',
#   u'-1',
#   u'-1',
#   u'1',
#   u'1',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'0',
#   u'-1',
#   u'0',
#   u'-1',
#   u'0',
#   u'1',
#   u'0',
#   u'1',
#   u'-1'],
#  ...]

# %%
data_arff.keys()
# Out:
# [u'attributes', u'relation', u'description', u'data']

# %%
pd.DataFrame(data_arff['data'], columns = column_names)
#list of lists into PandasDataFrame
#now next step add column_names
# Out:
#      having_IP_Address URL_Length Shortining_Service having_At_Symbol  \
# 0                    1          1                  0                0
# 1                    0          1                  0                0
# 2                    0          0                  0                0
# 3                    0          0                  0                0
# 4                    0          0                  1                0
# 5                    1          0                  1                0
# 6                    0         -1                  0                0
# 7                    0         -1                  0                0
# 8                    0          0                  0                0
# 9                    0          0                  0                0
# 10                   0          0                  0                0
# 11                   0          0                  0                0
# 12                   0          0                  0                0
# 13                   0          1                  0                0
# 14                   0         -1                  0                0
# 15                   0         -1                  0                0
# 16                   1         -1                  1                0
# 17                   0         -1                  0                0
# 18                   0         -1                  0                0
# 19                   0         -1                  0                1
# 20                   0          1                  0                0
